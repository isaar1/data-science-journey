# %% [raw]
# 📝 Task 1: Filtering Data
# Try these filtering tasks using your sales dataset:
# 1️⃣ Get all sales where Total is greater than 500.
# 2️⃣ Get all transactions made by female customers.
# 3️⃣ Get all purchases of "Health and Beauty" products.

# %%
import pandas as pd

df = pd.read_csv("cleaned_sales_data.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200   80.2200
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880  489.0480
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date  Time      Payment    cogs  gross margin percentage  \
# 0  2019-01-05    13      Ewallet  522.83                 4.761905
# 1  2019-03-08    10         Cash   76.40                 4.761905
# ...

# %% [markdown]
# ## 1️⃣ Get all sales where Total is greater than 500

# %%
high_value_sales = df[df["Total"] > 500]
high_value_sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 14   829-34-3910      A     Yangon        Normal  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380      C  Naypyitaw        Member    Male
# 989  430-53-4718      B   Mandalay        Member    Male
# 991  602-16-6955      B   Mandalay        Normal  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ...

# %% [markdown]
# ## 2️⃣ Get all transactions made by female customers

# %%
female_customers = df[df["Gender"] == "Female"]
female_customers
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 990  886-18-2897      A     Yangon        Normal  Female
# 991  602-16-6955      B   Mandalay        Normal  Female
# 994  652-49-6720      C  Naypyitaw        Member  Female
# 996  303-96-2227      B   Mandalay        Normal  Female
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ## 3️⃣ Get all purchases of "Health and Beauty" products

# %%
health_beauty_sales = df[df["Product line"] == "Health and beauty"]
health_beauty_sales
# Out:
#       Invoice ID Branch       City Customer type  Gender       Product line  \
# 0    750-67-8428      A     Yangon        Member  Female  Health and beauty
# 3    123-19-1176      A     Yangon        Member    Male  Health and beauty
# 8    665-32-9167      A     Yangon        Member  Female  Health and beauty
# 14   829-34-3910      A     Yangon        Normal  Female  Health and beauty
# 16   656-95-9349      A     Yangon        Member  Female  Health and beauty
# ..           ...    ...        ...           ...     ...                ...
# 983  148-41-7930      C  Naypyitaw        Normal    Male  Health and beauty
# 986  764-44-8999      B   Mandalay        Normal  Female  Health and beauty
# 987  552-44-5977      B   Mandalay        Member    Male  Health and beauty
# 989  430-53-4718      B   Mandalay        Member    Male  Health and beauty
# 995  233-67-5758      C  Naypyitaw        Normal    Male  Health and beauty
#
# ...

# %% [raw]
# 📝 Task 2: Grouping & Aggregation
# 1️⃣ Find the total sales per product line.
# 2️⃣ Find the average rating per city.
# 3️⃣ Find the total quantity sold per branch.

# %% [markdown]
# ## 1️⃣ Find the total sales per product line

# %%
total_sales_per_product = df.groupby("Product line")["Total"].sum()

total_sales_per_product
# Out:
# Product line
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Food and beverages        56144.8440
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Sports and travel         55122.8265
# Name: Total, dtype: float64

# %% [markdown]
# ## 2️⃣ Find the average rating per city

# %%
avg_rating_per_city = df.groupby("City")["Rating"].mean()

avg_rating_per_city
# Out:
# City
# Mandalay     6.818072
# Naypyitaw    7.072866
# Yangon       7.027059
# Name: Rating, dtype: float64

# %% [markdown]
# ## 3️⃣ Find the total quantity sold per branch

# %%
total_quantity_per_branch = df.groupby("Branch")["Quantity"].sum()

total_quantity_per_branch
# Out:
# Branch
# A    1859
# B    1820
# C    1831
# Name: Quantity, dtype: int64
